# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as ply

# %%
weather = pd.read_csv('weather.csv', parse_dates=['Date.Full'], dayfirst=True)

# %% [markdown]
# - understanding the datas

# %%
weather.head() #first 5 records
# Out:
#    Precipitation       Date  Month  Week  Year        City Code  \
# 0           0.00 2016-01-03      1     3  2016  Birmingham  BHM
# 1           0.00 2016-01-03      1     3  2016  Huntsville  HSV
# 2           0.16 2016-01-03      1     3  2016      Mobile  MOB
# 3           0.00 2016-01-03      1     3  2016  Montgomery  MGM
# 4           0.01 2016-01-03      1     3  2016   Anchorage  ANC
#
#          Location    State  Avg Temp  MaxTemp  MinTemp  WindDirection  \
# 0  Birmingham, AL  Alabama        39       46       32             33
# 1  Huntsville, AL  Alabama        39       47       31             32
# 2      Mobile, AL  Alabama        46       51       41             35
# 3  Montgomery, AL  Alabama        45       52       38             32
# 4   Anchorage, AK   Alaska        34       38       29             19
#
#    WindSpeed
# 0       4.33
# 1       3.86
# 2       9.73
# 3       6.86
# 4       7.80

# %%
weather.tail() #last 5 records
# Out:
#        Precipitation       Date  Month  Week  Year      City Code  \
# 16738           0.08 2017-01-01      1     1  2017    Casper  CPR
# 16739           0.00 2017-01-01      1     1  2017  Cheyenne  CYS
# 16740           0.00 2017-01-01      1     1  2017    Lander  LND
# 16741           0.06 2017-01-01      1     1  2017   Rawlins  RWL
# 16742           0.10 2017-01-01      1     1  2017  Sheridan  SHR
#
#            Location    State  Avg Temp  MaxTemp  MinTemp  WindDirection  \
# 16738    Casper, WY  Wyoming        23       32       15             23
# 16739  Cheyenne, WY  Wyoming        32       42       21             26
# 16740    Lander, WY  Wyoming        17       29        4             26
# 16741   Rawlins, WY  Wyoming        23       31       13             24
# 16742  Sheridan, WY  Wyoming        21       34        8             23
#
#        WindSpeed
# 16738      19.98
# 16739      15.16
# 16740       1.65
# 16741      18.16
# 16742       7.51

# %%
weather.head(30) #first n records
# Out:
#     Precipitation       Date  Month  Week  Year                      City  \
# 0            0.00 2016-01-03      1     3  2016                Birmingham
# 1            0.00 2016-01-03      1     3  2016                Huntsville
# 2            0.16 2016-01-03      1     3  2016                    Mobile
# 3            0.00 2016-01-03      1     3  2016                Montgomery
# 4            0.01 2016-01-03      1     3  2016                 Anchorage
# 5            0.09 2016-01-03      1     3  2016                   Annette
# 6            0.05 2016-01-03      1     3  2016                    Bethel
# 7            0.15 2016-01-03      1     3  2016                   Bettles
# 8            0.60 2016-01-03      1     3  2016                  Cold Bay
# 9            2.15 2016-01-03      1     3  2016                   Cordova
# 10           0.00 2016-01-03      1     3  2016  Delta Junction/Ft Greely
# 11           0.00 2016-01-03      1     3  2016                 Fairbanks
# ...

# %%
weather.info() #dataframe structure summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16743 entries, 0 to 16742
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Data.Precipitation         16743 non-null  float64
#  1   Date.Full                  16743 non-null  datetime64[ns]
#  2   Date.Month                 16743 non-null  int64
#  3   Date.Week of               16743 non-null  int64
#  4   Date.Year                  16743 non-null  int64
#  5   Station.City               16743 non-null  object
#  6   Station.Code               16743 non-null  object
#  7   Station.Location           16743 non-null  object
#  8   Station.State              16743 non-null  object
#  9   Data.Temperature.Avg Temp  16743 non-null  int64
#  10  Data.Temperature.Max Temp  16743 non-null  int64
#  11  Data.Temperature.Min Temp  16743 non-null  int64
#  12  Data.Wind.Direction        16743 non-null  int64
# ...

# %%
weather.describe()
# Out:
#        Data.Precipitation    Date.Month  Date.Week of     Date.Year  \
# count        16743.000000  16743.000000  16743.000000  16743.000000
# mean             0.579090      6.343128     15.650242   2016.018933
# std              0.988057      3.490723      8.923425      0.136294
# min              0.000000      1.000000      1.000000   2016.000000
# 25%              0.000000      3.000000      8.000000   2016.000000
# 50%              0.190000      6.000000     16.000000   2016.000000
# 75%              0.750000      9.000000     24.000000   2016.000000
# max             20.890000     12.000000     31.000000   2017.000000
#
#        Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# count               16743.000000               16743.000000
# mean                   56.089112                  66.042406
# std                    18.798295                  19.787954
# min                   -27.000000                 -19.000000
# ...

# %%
weather.describe(include='object')
# Out:
#        Station.City Station.Code Station.Location Station.State
# count         16743        16743            16743         16743
# unique          307          318              318            53
# top         Norfolk          BHM   Birmingham, AL        Alaska
# freq            106           53               53          1719

# %%
weather.columns.tolist()
# Out:
# ['Data.Precipitation',
#  'Date.Full',
#  'Date.Month',
#  'Date.Week of',
#  'Date.Year',
#  'Station.City',
#  'Station.Code',
#  'Station.Location',
#  'Station.State',
#  'Data.Temperature.Avg Temp',
#  'Data.Temperature.Max Temp',
#  'Data.Temperature.Min Temp',
#  'Data.Wind.Direction',
#  'Data.Wind.Speed']

# %% [markdown]
# - rename the column names if necessary
#  - df.columns = list of newcolumns
#  - pd.rename() can also be used when changing names of columns or index

# %%
weather.columns = ['Precipitation','Date','Month','Week','Year','City','Code','Location','State','Avg Temp','MaxTemp','MinTemp','WindDirection','WindSpeed']

# %%
weather.head(3)
# Out:
#    Precipitation       Date  Month  Week  Year        City Code  \
# 0           0.00 2016-01-03      1     3  2016  Birmingham  BHM
# 1           0.00 2016-01-03      1     3  2016  Huntsville  HSV
# 2           0.16 2016-01-03      1     3  2016      Mobile  MOB
# 3           0.00 2016-01-03      1     3  2016  Montgomery  MGM
# 4           0.01 2016-01-03      1     3  2016   Anchorage  ANC
#
#          Location    State  Avg Temp  MaxTemp  MinTemp  WindDirection  \
# 0  Birmingham, AL  Alabama        39       46       32             33
# 1  Huntsville, AL  Alabama        39       47       31             32
# 2      Mobile, AL  Alabama        46       51       41             35
# 3  Montgomery, AL  Alabama        45       52       38             32
# 4   Anchorage, AK   Alaska        34       38       29             19
#
#    WindSpeed
# 0       4.33
# 1       3.86
# 2       9.73
# 3       6.86
# 4       7.80

# %% [markdown]
# - selecting rows and columns
#     - rows(slicing)
#         - 'loc' - gets us the data using named indexes
#         - 'iloc' - gets us the data using numeric indexes
#
#
#         - df[single] - requires name of column
#         - df[multiple] - requires a list of columns(multiplenis list of named cols)

# %%
weather.iloc[0]
# Out:
# Precipitation                    0.0
# Date             2016-01-03 00:00:00
# Month                              1
# Week                               3
# Year                            2016
# City                      Birmingham
# Code                             BHM
# Location              Birmingham, AL
# State                        Alabama
# Avg Temp                          39
# MaxTemp                           46
# MinTemp                           32
# WindDirection                     33
# WindSpeed                       4.33
# Name: 0, dtype: object

# %%
weather.iloc[-1]
# Out:
# Precipitation                    0.1
# Date             2017-01-01 00:00:00
# Month                              1
# Week                               1
# Year                            2017
# City                        Sheridan
# Code                             SHR
# Location                Sheridan, WY
# State                        Wyoming
# Avg Temp                          21
# MaxTemp                           34
# MinTemp                            8
# WindDirection                     23
# WindSpeed                       7.51
# Name: 16742, dtype: object

# %%
#weather.iloc[25:50] #records 25-50

# %%
#records 1-15 with first 5 col
weather.iloc[1:16, :5]
# Out:
#     Precipitation       Date  Month  Week  Year
# 1            0.00 2016-01-03      1     3  2016
# 2            0.16 2016-01-03      1     3  2016
# 3            0.00 2016-01-03      1     3  2016
# 4            0.01 2016-01-03      1     3  2016
# 5            0.09 2016-01-03      1     3  2016
# 6            0.05 2016-01-03      1     3  2016
# 7            0.15 2016-01-03      1     3  2016
# 8            0.60 2016-01-03      1     3  2016
# 9            2.15 2016-01-03      1     3  2016
# 10           0.00 2016-01-03      1     3  2016
# 11           0.00 2016-01-03      1     3  2016
# 12           0.02 2016-01-03      1     3  2016
# 13           1.22 2016-01-03      1     3  2016
# 14           0.00 2016-01-03      1     3  2016
# 15           0.70 2016-01-03      1     3  2016

# %%
#records 1-15 with first 5 col
weather.iloc[1:16, [0,1,2,3,4]]
# Out:
#     Precipitation       Date  Month  Week  Year
# 1            0.00 2016-01-03      1     3  2016
# 2            0.16 2016-01-03      1     3  2016
# 3            0.00 2016-01-03      1     3  2016
# 4            0.01 2016-01-03      1     3  2016
# 5            0.09 2016-01-03      1     3  2016
# 6            0.05 2016-01-03      1     3  2016
# 7            0.15 2016-01-03      1     3  2016
# 8            0.60 2016-01-03      1     3  2016
# 9            2.15 2016-01-03      1     3  2016
# 10           0.00 2016-01-03      1     3  2016
# 11           0.00 2016-01-03      1     3  2016
# 12           0.02 2016-01-03      1     3  2016
# 13           1.22 2016-01-03      1     3  2016
# 14           0.00 2016-01-03      1     3  2016
# 15           0.70 2016-01-03      1     3  2016

# %%
# 15 recordswith last 3 cols
weather.iloc[:15, -3:]
# Out:
#     MinTemp  WindDirection  WindSpeed
# 0        32             33       4.33
# 1        31             32       3.86
# 2        41             35       9.73
# 3        38             32       6.86
# 4        29             19       7.80
# 5        31              9       8.70
# 6        24              9      16.46
# 7         9              2       3.10
# 8        31             20       9.10
# 9        33              9       9.76
# 10       23             14      17.90
# 11        4              2       2.20
# 12       19             14       8.23
# 13       35              9      11.26
# 14       37              9      19.76

# %%
#15 records with last 3 col
weather.iloc[:15, [-3,-2,-1]]
# Out:
#     MinTemp  WindDirection  WindSpeed
# 0        32             33       4.33
# 1        31             32       3.86
# 2        41             35       9.73
# 3        38             32       6.86
# 4        29             19       7.80
# 5        31              9       8.70
# 6        24              9      16.46
# 7         9              2       3.10
# 8        31             20       9.10
# 9        33              9       9.76
# 10       23             14      17.90
# 11        4              2       2.20
# 12       19             14       8.23
# 13       35              9      11.26
# 14       37              9      19.76

# %%
weather['Date']
# Out:
# 0       2016-01-03
# 1       2016-01-03
# 2       2016-01-03
# 3       2016-01-03
# 4       2016-01-03
#            ...
# 16738   2017-01-01
# 16739   2017-01-01
# 16740   2017-01-01
# 16741   2017-01-01
# 16742   2017-01-01
# Name: Date, Length: 16743, dtype: datetime64[ns]

# %%
weather.AvgTemp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\hp\Documents\Python_Data_Science\datascience\data_analaysis1.ipynb Cell 23 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hp/Documents/Python_Data_Science/datascience/data_analaysis1.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> weather.AvgTemp
#
# File c:\Users\hp\miniconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'AvgTemp'

# %%
cols =

# %% [markdown]
# # SIMPLE VISUALISATION

# %%
weather['Precipitation'].plot()
# Out:
# <AxesSubplot: >

# %%
weather['Precipitation'].plot(figsize=(20,7))
# Out:
# <AxesSubplot: >

# %%
weather['Precipitation'].plot(figsize=(20,7), kind='hist', bins=50)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
weather['Precipitation'].plot(figsize=(20,7), kind='kde')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
#weather[['MaxTemp', 'MinTemp']].plot(figsize=(20,6), 
    kind='hist', color=['green', 'hotpink'], bins=25, alpha=.5, subplot=True, Layout=(2,1))
# Out:
#   Input In [45]
#     kind='hist', color=['green', 'hotpink'], bins=25, alpha=.5, subplot=True, Layout=(2,1))
#     ^
# IndentationError: unexpected indent
